# %%
import pandas as pd

pres = pd.read_csv('../dataset/Elections Dataset/pres_precinct_data_2022.csv')
pres # When displaying a DataFrame, the first and last 5 rows will be shown by default:
# Out:
#             Region  Province     City                Barangay  Precinct ID  \
# 0         REGION X  BUKIDNON  BAUNGON                BALINTAD     13010009
# 1         REGION X  BUKIDNON  BAUNGON              BUENAVISTA     13010010
# 2         REGION X  BUKIDNON  BAUNGON                 DANATAG     13010011
# 3         REGION X  BUKIDNON  BAUNGON                 DANATAG     13010012
# 4         REGION X  BUKIDNON  BAUNGON                 DANATAG     13010013
# ...            ...       ...      ...                     ...          ...
# 105661  REGION III    BATAAN    SAMAL                    GUGO      8120018
# 105662  REGION III    BATAAN    SAMAL  WEST CALAGUIMAN (POB.)      8120049
# 105663  REGION III    BATAAN    SAMAL  WEST CALAGUIMAN (POB.)      8120050
# 105664  REGION III    BATAAN    SAMAL  WEST DAANG BAGO (POB.)      8120003
# 105665  REGION III    BATAAN    SAMAL  WEST DAANG BAGO (POB.)      8120004
#
#         ABELLA, ERNIE (IND)  DE GUZMAN, LEODY (PLM)  \
# 0                         2                       1
# 1                         3                       5
# 2                         4                       3
# 3                         2                       2
# 4                         0                       1
# ...                     ...                     ...
# 105661                    3                       0
# 105662                    2                       0
# 105663                    0                       0
# 105664                    3                       1
# 105665                    1                       0
#
#         DOMAGOSO, ISKO MORENO (AKSYON)  GONZALES, NORBERTO (PDSP)  \
# 0                                    4                          0
# 1                                    7                          5
# 2                                    9                          4
# 3                                   16                          2
# 4                                   16                          4
# ...                                ...                        ...
# 105661                              38                          0
# 105662                              58                          2
# 105663                              37                          1
# 105664                              20                          2
# 105665                              26                          2
#
#         LACSON, PING (PDR)  MANGONDATO, FAISAL (KTPNAN)  \
# 0                        0                            1
# 1                        0                            2
# 2                        3                            0
# 3                        3                            0
# 4                        6                            0
# ...                    ...                          ...
# 105661                   7                            0
# 105662                   5                            1
# 105663                  10                            0
# 105664                  11                            0
# 105665                  12                            0
#
#         MARCOS, BONGBONG (PFP)  MONTEMAYOR, JOSE JR. (DPP)  \
# 0                          224                           0
# 1                          310                           1
# 2                          288                           4
# 3                          190                           3
# 4                          272                           2
# ...                        ...                         ...
# 105661                     347                           1
# 105662                     243                           0
# 105663                     233                           1
# 105664                     194                           0
# 105665                     215                           0
#
#         PACQUIAO, MANNY PACMAN(PROMDI)  ROBREDO, LENI (IND)
# 0                                  115                   29
# 1                                  188                   47
# 2                                  152                   44
# 3                                  160                   51
# 4                                  125                   46
# ...                                ...                  ...
# 105661                              12                  124
# 105662                               7                  197
# 105663                               5                  236
# 105664                               9                  127
# 105665                               2                  138
#
# [105666 rows x 15 columns]

# %%
pres.dtypes # A check on how pandas interpreted each of the column data types can be done by requesting the pandas dtypes attribute:
# Out:
# Region                            object
# Province                          object
# City                              object
# Barangay                          object
# Precinct ID                        int64
# ABELLA, ERNIE (IND)                int64
# DE GUZMAN, LEODY (PLM)             int64
# DOMAGOSO, ISKO MORENO (AKSYON)     int64
# GONZALES, NORBERTO (PDSP)          int64
# LACSON, PING (PDR)                 int64
# MANGONDATO, FAISAL (KTPNAN)        int64
# MARCOS, BONGBONG (PFP)             int64
# MONTEMAYOR, JOSE JR. (DPP)         int64
# PACQUIAO, MANNY PACMAN(PROMDI)     int64
# ROBREDO, LENI (IND)                int64
# dtype: object

# %%
pres.info() # technical summary of a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105666 entries, 0 to 105665
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Region                          105666 non-null  object
#  1   Province                        105666 non-null  object
#  2   City                            105666 non-null  object
#  3   Barangay                        105666 non-null  object
#  4   Precinct ID                     105666 non-null  int64
#  5   ABELLA, ERNIE (IND)             105666 non-null  int64
#  6   DE GUZMAN, LEODY (PLM)          105666 non-null  int64
#  7   DOMAGOSO, ISKO MORENO (AKSYON)  105666 non-null  int64
#  8   GONZALES, NORBERTO (PDSP)       105666 non-null  int64
#  9   LACSON, PING (PDR)              105666 non-null  int64
#  10  MANGONDATO, FAISAL (KTPNAN)     105666 non-null  int64
#  11  MARCOS, BONGBONG (PFP)          105666 non-null  int64
#  12  MONTEMAYOR, JOSE JR. (DPP)      105666 non-null  int64
#  13  PACQUIAO, MANNY PACMAN(PROMDI)  105666 non-null  int64
#  14  ROBREDO, LENI (IND)             105666 non-null  int64
# dtypes: int64(11), object(4)
# memory usage: 12.1+ MB

# %%
votes = pres[[
    "ABELLA, ERNIE (IND)",
    "DE GUZMAN, LEODY (PLM)",
    "DOMAGOSO, ISKO MORENO (AKSYON)",
    "GONZALES, NORBERTO (PDSP)",
    "LACSON, PING (PDR)",
    "MANGONDATO, FAISAL (KTPNAN)",
    "MARCOS, BONGBONG (PFP)",
    "MONTEMAYOR, JOSE JR. (DPP)",
    "PACQUIAO, MANNY PACMAN(PROMDI)",
    "ROBREDO, LENI (IND)"
]]
votes.plot(figsize=(10,10))
votes.plot(figsize=(12,4), subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
top2 = pres[["MARCOS, BONGBONG (PFP)", "ROBREDO, LENI (IND)"]] # Select a subset
print(pres[["Precinct ID", "MARCOS, BONGBONG (PFP)", "ROBREDO, LENI (IND)"]])
top2.plot()
# Out:
#         Precinct ID  MARCOS, BONGBONG (PFP)  ROBREDO, LENI (IND)
# 0          13010009                     224                   29
# 1          13010010                     310                   47
# 2          13010011                     288                   44
# 3          13010012                     190                   51
# 4          13010013                     272                   46
# ...             ...                     ...                  ...
# 105661      8120018                     347                  124
# 105662      8120049                     243                  197
# 105663      8120050                     233                  236
# 105664      8120003                     194                  127
# 105665      8120004                     215                  138
#
# [105666 rows x 3 columns]
# <AxesSubplot:>

# %%
top2.plot.scatter(x="MARCOS, BONGBONG (PFP)", y="ROBREDO, LENI (IND)", alpha=0.75)
# Out:
# <AxesSubplot:xlabel='MARCOS, BONGBONG (PFP)', ylabel='ROBREDO, LENI (IND)'>

# %%
pres["ratio_robredo_marcos"] = (pres["ROBREDO, LENI (IND)"] / pres["MARCOS, BONGBONG (PFP)"])
pres[pres["ratio_robredo_marcos"] == 1.0] # TODO compare to 2016 vp ?
# Out:
#              Region          Province            City     Barangay  \
# 47         REGION X          BUKIDNON         DAMULOG     ANGGA-AN
# 7121    REGION XIII  AGUSAN DEL NORTE        SANTIAGO       LA PAZ
# 7405    REGION XIII    AGUSAN DEL SUR       ESPERANZA  SAN VICENTE
# 7434    REGION XIII    AGUSAN DEL SUR          LA PAZ        LYDIA
# 8004          BARMM     LANAO DEL SUR       BALINDONG      DIMARAO
# ...             ...               ...             ...          ...
# 103299   REGION III            TARLAC  CITY OF TARLAC        ATIOC
# 103520   REGION III            TARLAC  CITY OF TARLAC  SAN VICENTE
# 103564   REGION III            TARLAC  CITY OF TARLAC        SUIZO
# 103730   REGION III          ZAMBALES         BOTOLAN     POONBATO
# 104564   REGION III            AURORA           BALER     SUCLAYIN
#
#         Precinct ID  ABELLA, ERNIE (IND)  DE GUZMAN, LEODY (PLM)  \
# 47         13020009                    7                       5
# 7121        2100019                    0                       1
# 7405        3030057                    3                       2
# 7434        3040021                    0                       0
# 8004       36030016                    0                       0
# ...             ...                  ...                     ...
# 103299     69160021                    1                       1
# 103520     69160249                    1                       2
# 103564     69160293                    2                       0
# 103730     71010049                    4                       0
# 104564     77010036                    1                       1
#
#         DOMAGOSO, ISKO MORENO (AKSYON)  GONZALES, NORBERTO (PDSP)  \
# 47                                  11                          5
# 7121                                 1                          1
# 7405                                 0                          2
# 7434                                 0                          0
# 8004                                 0                          0
# ...                                ...                        ...
# 103299                              24                          2
# 103520                              24                          0
# 103564                              14                          0
# 103730                               6                          3
# 104564                              21                          0
#
#         LACSON, PING (PDR)  MANGONDATO, FAISAL (KTPNAN)  \
# 47                       2                            4
# 7121                     2                            0
# 7405                     0                            0
# 7434                     1                            0
# 8004                     1                           96
# ...                    ...                          ...
# 103299                   9                            0
# 103520                   6                            1
# 103564                  13                            2
# 103730                  15                            0
# 104564                  36                            0
#
#         MARCOS, BONGBONG (PFP)  MONTEMAYOR, JOSE JR. (DPP)  \
# 47                          89                           0
# 7121                       190                           0
# 7405                       132                           0
# 7434                         5                           0
# 8004                        22                           2
# ...                        ...                         ...
# 103299                     262                           0
# 103520                     273                           1
# 103564                     300                           0
# 103730                     251                           1
# 104564                     267                           0
#
#         PACQUIAO, MANNY PACMAN(PROMDI)  ROBREDO, LENI (IND)  \
# 47                                 127                   89
# 7121                                33                  190
# 7405                                45                  132
# 7434                               142                    5
# 8004                                 1                   22
# ...                                ...                  ...
# 103299                               4                  262
# 103520                               9                  273
# 103564                               9                  300
# 103730                              14                  251
# 104564                               7                  267
#
#         ratio_robredo_marcos
# 47                       1.0
# 7121                     1.0
# 7405                     1.0
# 7434                     1.0
# 8004                     1.0
# ...                      ...
# 103299                   1.0
# 103520                   1.0
# 103564                   1.0
# 103730                   1.0
# 104564                   1.0
#
# [142 rows x 16 columns]

# %%
pres[(pres["Barangay"] == "MAYSAN") & (pres["City"] == "CITY OF VALENZUELA")][["MARCOS, BONGBONG (PFP)", "ROBREDO, LENI (IND)"]].sum()
# Out:
# MARCOS, BONGBONG (PFP)    9233
# ROBREDO, LENI (IND)       4581
# dtype: int64

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(pres, title="Pandas Profiling Report")
profile.to_file("Pres - Pandas Profiling Report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\halloween\AppData\Local\pypoetry\Cache\virtualenvs\pjdsc-7i-rjEyF-py3.9\lib\site-packages\scipy\stats\stats.py:4594: RuntimeWarning: overflow encountered in longlong_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
